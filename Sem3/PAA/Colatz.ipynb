# %%
import math
import matplotlib.pyplot as plt

class AlgorithmAnalys:
    def __init__(self) -> None:
        self.results = []
        self.indexes = []
        self.Ni = 0
    
    def add_result(self, index, result):
        self.results.append(result)
        # self.Ni += 1
        # self.indexes.append(self.Ni)
        self.indexes.append(index)
        
    def plot(self, color = "red"):        
        plt.plot(self.indexes, self.results, color = color)

        plt.title("Algorithm")
        plt.xlabel("k")
        plt.ylabel("Nsteps")

        # Set x-axis ticks to integers with step 1
        # plt.xticks(range(1, self.Ni + 1, 1))
        # plt.yticks(range(1, self.Ni * 3, 1))

        plt.show()

# %%
def Collatz(k):
    Nsteps = 0

    if (k == 1):
        return 1
    
    while(k != 1):
        if (k % 2 == 0):
            k /= 2
        else:
            k = 3 * k + 1
        Nsteps += 1

    return Nsteps

# %%
analys = AlgorithmAnalys()

for k in range(7081,7100,1):
    analys.add_result(k, Collatz(k + 1))

analys.plot()
